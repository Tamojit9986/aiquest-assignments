# %% [markdown]
# # CardioVascular Disease project:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cardio_train.csv",sep =";") #sep is used as parametre if the datas doesnt fit properly to their respective columns
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
x = df.iloc[:, :-1]
x
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active
# ...

# %%
y = df.iloc[:, -1]
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
df.shape
# Out:
# (70000, 13)

# %%
df["cardio"].value_counts() #from cardio column we verify types of data using value_counts
# Out:
# 0    35021
# 1    34979
# Name: cardio, dtype: int64

# %%
#we need to visualize the data for cardio column (patients)

# %%
import seaborn

# %%
seaborn.countplot(df["cardio"]) #countplot is used to catagorizr the data in vidual format
# Out:
# D:\Python\project1\venv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cardio', ylabel='count'>

# %%
#To ensure if we have null values

# %%
df.isnull().sum() #since we got no null values so no need to handle via mean,median
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
#To visualize the gender column with respect to cardio column using seaborn

# %%
seaborn.countplot(x = "gender",hue="cardio",data=df,palette = "colorblind",edgecolor=seaborn.color_palette("dark",n_colors=1))
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
#To visualize data of age column with respect to cardio column

# %%
seaborn.countplot(x = "age",hue="cardio",data=df,palette = "colorblind",edgecolor=seaborn.color_palette("dark",n_colors=1))
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
#since the age column is in days not in years so we will be making the age column in years and round figure

# %%
#df["yr"]=(df["age"]//365) #without using round funtion

# %%
#df["yr"]

# %%
df["yr"]=(df["age"]/365).round(0)

# %%
df["yr"] #using round function
# Out:
# 0        50.0
# 1        55.0
# 2        52.0
# 3        48.0
# 4        48.0
#          ...
# 69995    53.0
# 69996    62.0
# 69997    52.0
# 69998    61.0
# 69999    56.0
# Name: yr, Length: 70000, dtype: float64

# %%
seaborn.countplot(x = "yr",hue="cardio",data=df,palette = "colorblind",edgecolor=seaborn.color_palette("dark",n_colors=1))
# Out:
# <AxesSubplot:xlabel='yr', ylabel='count'>

# %%
#To find the corelation among the columns

# %%
df.corr()
# Out:
#                    id       age    gender    height    weight     ap_hi  \
# id           1.000000  0.003457  0.003502 -0.003038 -0.001830  0.003356
# age          0.003457  1.000000 -0.022811 -0.081515  0.053684  0.020764
# gender       0.003502 -0.022811  1.000000  0.499033  0.155406  0.006005
# height      -0.003038 -0.081515  0.499033  1.000000  0.290968  0.005488
# weight      -0.001830  0.053684  0.155406  0.290968  1.000000  0.030702
# ap_hi        0.003356  0.020764  0.006005  0.005488  0.030702  1.000000
# ap_lo       -0.002529  0.017647  0.015254  0.006150  0.043710  0.016086
# cholesterol  0.006106  0.154424 -0.035821 -0.050226  0.141768  0.023778
# gluc         0.002467  0.098703 -0.020491 -0.018595  0.106857  0.011841
# smoke       -0.003699 -0.047633  0.338135  0.187989  0.067780 -0.000922
# alco         0.001210 -0.029723  0.170966  0.094419  0.067113  0.001408
# active       0.003755 -0.009927  0.005866 -0.006570 -0.016867 -0.000033
# ...

# %%
x
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = .25,random_state =1) #data splitting

# %% [markdown]
# # Through RandomForest Algorithm:

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
r = RandomForestClassifier()

# %%
r.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
r.predict(xtest)
# Out:
# array([1, 0, 1, ..., 1, 1, 0], dtype=int64)

# %%
r.score(xtest,ytest)
# Out:
# 0.7262285714285714

# %% [markdown]
# # Through Decision Tree Algorithm:

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dct = DecisionTreeClassifier()

# %%
dct.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
dct.score(xtest,ytest) #To measure accuracy
# Out:
# 0.6248571428571429

# %%
df
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio    yr
# ...
